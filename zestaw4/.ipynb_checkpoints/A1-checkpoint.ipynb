# %%
import random
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
def exponential(l):
    u = random.random()
    return -math.log(u)/l

# %%
lambda_a = 2
lambda_d = 2.5
n_of_tasks=10

# %%
tasks=[]
for i in range(n_of_tasks):
    tasks.append(exponential(lambda_a))

# %%
task_id=0
task_t=tasks[task_id]
queue=[]
queue.append([task_id,task_t])
serwer_t=exponential(lambda_d)  
t=0
executed=0
tasks_in_queue=[]
time_waited=[]
executed_tasks=[]

# %%
while(executed<n_of_tasks):
    if(task_t<=0 and task_id<n_of_tasks):
        task_id+=1
        task_t=tasks[task_id]
        queue.append(t)
        print(t)
        tasks_in_queue.append([t,len(queue)])
    if(len(queue)>0):
        if(serwer_t<=0):
            serwer_t=exponential(lambda_d)
            temp = queue.pop(0)
            #print(temp)
            executed+=1
            time_waited.append(t-temp)
            tasks_in_queue.append([t,len(queue)])
            executed_tasks.append([t,executed])
        serwer_t-=1/60
    task_t-=1/60
    t+=1/60   
    print(t)
# Out:
# 0.016666666666666666
# 0.03333333333333333
# 0.05
# 0.06666666666666667
# 0.08333333333333333
# 0.09999999999999999
# 0.11666666666666665
# 0.13333333333333333
# 0.15
# 0.16666666666666666
# 0.18333333333333332
# 0.19999999999999998
# 0.21666666666666665
# 0.21666666666666665
# 0.2333333333333333
# 0.24999999999999997
# 0.26666666666666666
# 0.2833333333333333
# 0.3
# 0.31666666666666665
# 0.3333333333333333
# 0.35
# 0.36666666666666664
# 0.3833333333333333
# 0.39999999999999997
# 0.41666666666666663
# 0.4333333333333333
# 0.44999999999999996
# 0.4666666666666666
# 0.4833333333333333
# 0.49999999999999994
# 0.5166666666666666
# 0.5333333333333333
# 0.55
# 0.5666666666666668
# 0.5833333333333335
# 0.6000000000000002
# 0.6166666666666669
# 0.6333333333333336
# 0.6500000000000004
# 0.6666666666666671
# 0.6833333333333338
# 0.7000000000000005
# 0.7166666666666672
# 0.733333333333334
# 0.7500000000000007
# 0.7666666666666674
# 0.7833333333333341
# 0.8000000000000008
# 0.8166666666666675
# 0.8333333333333343
# 0.850000000000001
# 0.8666666666666677
# 0.8833333333333344
# 0.9000000000000011
# 0.9166666666666679
# 0.9333333333333346
# 0.9500000000000013
# 0.966666666666668
# 0.9833333333333347
# 1.0000000000000013
# 1.016666666666668
# 1.0333333333333345
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12832/373367983.py in <module>
#      12             #print(temp)
#      13             executed+=1
# ---> 14             time_waited.append(t-temp)
#      15             tasks_in_queue.append([t,len(queue)])
#      16             executed_tasks.append([t,executed])
#
# TypeError: unsupported operand type(s) for -: 'float' and 'list'

# %%
#print(tasks_in_queue)
print(executed_tasks)
# Out:
# []

# %%
while(t<t_max):
    if(task_t<=0):
        task_t=exponential(lambda_a)
        queue+=1
        send+=1
    if(queue>0):
        if(serwer_t<=0):
            serwer_t=exponential(lambda_d)
            queue-=1
            executed+=1
        serwer_t-=1/60
    task_t-=1/60
    t+=1/60
    results["queue"].append(queue)
    results["executed"].append(executed)
    results["send"].append(send)

time_waited=[]    
tasks = set(results["executed"])
tasks.remove(0)
for t in tasks:
    t_send = results["send"].index(t)
    t_exec = results["executed"].index(t)
    time_waited.append((t_exec-t_send)/60)

# %%
plots = len(results.keys())
fig,ax = plt.subplots(plots+1,figsize=(20,20))

ax[0].set_title("tasks in queue")
ax[0].scatter([i/60 for i in range(0,t_max*60)],results["queue"])
ax[1].set_title("send in time")
ax[1].bar(list(tasks),time_waited)
ax[2].set_title("executed tasks")
ax[2].scatter([i/60 for i in range(0,t_max*60)],results["executed"])
ax[3].set_title("send tasks")
ax[3].scatter([i/60 for i in range(0,t_max*60)],results["send"])
